# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/heart_attack.csv')

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.shape
# Out:
# (918, 12)

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
def plotting(var , num):
  plt. subplot(2,2,num)
  sns.histplot(df[var], kde = True)

plotting('Age',1)
plotting('RestingECG',2)
plotting('MaxHR',3)
plotting('Cholesterol',4)

plt.tight_layout()

# %%
chol_mean = df.loc[df['Cholesterol'] != 0, 'Cholesterol'].mean()
df['cholestrol'] = df['Cholesterol'].replace(0, chol_mean)
df['cholestrol'] = df['cholestrol'].round(2)

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease  cholestrol
# 0              N      0.0       Up             0       289.0
# 1              N      1.0     Flat             1       180.0
# 2              N      0.0       Up             0       283.0
# 3              Y      1.5     Flat             1       214.0
# 4              N      0.0       Up             0       195.0

# %%
chol_mean = df.loc[df['RestingBP'] != 0, 'RestingBP'].mean()
df['RestingBP'] = df['RestingBP'].replace(0, chol_mean)
df['RestingBP'] = df['RestingBP'].round(2)

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA      140.0          289          0     Normal    172
# 1   49   F           NAP      160.0          180          0     Normal    156
# 2   37   M           ATA      130.0          283          0         ST     98
# 3   48   F           ASY      138.0          214          0     Normal    108
# 4   54   M           NAP      150.0          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease  cholestrol
# 0              N      0.0       Up             0       289.0
# 1              N      1.0     Flat             1       180.0
# 2              N      0.0       Up             0       283.0
# 3              Y      1.5     Flat             1       214.0
# 4              N      0.0       Up             0       195.0

# %%
sns.countplot(x='Sex',hue='HeartDisease',data=df)
plt.show()

# %%
sns.countplot(x='ChestPainType',hue='HeartDisease',data=df)
plt.show()

# %%
sns.countplot(x='ExerciseAngina',hue='HeartDisease',data=df)
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True) , annot = True)
plt.show()

# %%
df_encoded = pd.get_dummies(df,drop_first=True)

# %%
df_encoded.head()
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0   40      140.0          289          0    172      0.0             0
# 1   49      160.0          180          0    156      1.0             1
# 2   37      130.0          283          0     98      0.0             0
# 3   48      138.0          214          0    108      1.5             1
# 4   54      150.0          195          0    122      0.0             0
#
#    cholestrol  Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# 0       289.0   True               True              False             False
# 1       180.0  False              False               True             False
# 2       283.0   True               True              False             False
# 3       214.0  False              False              False             False
# 4       195.0   True              False               True             False
#
# ...

# %%
df_encoded = df_encoded.astype(int)

# %%
df_encoded.head()
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0   40        140          289          0    172        0             0
# 1   49        160          180          0    156        1             1
# 2   37        130          283          0     98        0             0
# 3   48        138          214          0    108        1             1
# 4   54        150          195          0    122        0             0
#
#    cholestrol  Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# 0         289      1                  1                  0                 0
# 1         180      0                  0                  1                 0
# 2         283      1                  1                  0                 0
# 3         214      0                  0                  0                 0
# 4         195      1                  0                  1                 0
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
x = df_encoded.drop('HeartDisease',axis=1)
y = df_encoded['HeartDisease']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
scaler = StandardScaler()
x_train_scaled= scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
x_train_scaled
# Out:
# array([[-1.24506731, -0.74576034,  0.372803  , ..., -0.83846064,
#         -1.03325003, -0.84792072],
#        [-1.8862362 , -0.1826618 ,  0.08614581, ..., -0.83846064,
#         -1.03325003,  1.17935554],
#        [ 0.25099346,  0.94353528,  0.12313384, ...,  1.19266183,
#          0.96781995, -0.84792072],
#        ...,
#        [ 0.67843939, -0.1826618 ,  0.49301407, ...,  1.19266183,
#         -1.03325003,  1.17935554],
#        [ 0.67843939,  1.05615499, -1.84647842, ...,  1.19266183,
#         -1.03325003,  1.17935554],
#        [-1.45879027,  0.94353528,  1.77834789, ..., -0.83846064,
#          0.96781995, -0.84792072]])

# %%
modals = {
    'LogisticRegression' : LogisticRegression(),
    'KNeighborsClassifier' : KNeighborsClassifier(),
    'DecisionTreeClassifier' : DecisionTreeClassifier(),
     'SVC' : SVC(),
    'Naice byes': GaussianNB()
}

# %%
result = []

# %%
from sklearn.metrics import f1_score

for name , modal in modals.items():
  modal.fit(x_train_scaled,y_train)
  y_pred = modal.predict(x_test_scaled)
  accuracy = accuracy_score(y_test,y_pred)
  f1 = f1_score(y_test,y_pred)
  result.append({
      "modal" : name,
      "accuracy" : accuracy,
      "f1_score" : f1
  })

# %%
result
# Out:
# [{'modal': 'LogisticRegression',
#   'accuracy': 0.875,
#   'f1_score': 0.8899521531100478},
#  {'modal': 'KNeighborsClassifier',
#   'accuracy': 0.8641304347826086,
#   'f1_score': 0.8792270531400966},
#  {'modal': 'DecisionTreeClassifier',
#   'accuracy': 0.7989130434782609,
#   'f1_score': 0.8195121951219512},
#  {'modal': 'SVC',
#   'accuracy': 0.8858695652173914,
#   'f1_score': 0.9023255813953488},
#  {'modal': 'Naice byes',
#   'accuracy': 0.8641304347826086,
#   'f1_score': 0.8792270531400966}]

# %%
import joblib


joblib.dump(modals['KNeighborsClassifier'],'heart_attack_modal.pkl')
joblib.dump(scaler , 'scaler.pkl')
joblib.dump(x.columns.tolist(),'columns.pkl')
# Out:
# ['columns.pkl']
